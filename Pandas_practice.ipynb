# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Series
#   - pandas의 기본 객체 중 하나
#   - numpy의 ndarray를 기반으로 인덱싱을 기능을 추가하여 1차원 배열을 나타냄
#   - index를 지정하지 않을 시, 기본적으로 ndarray와 같이 0-based 인덱스 생성, 지정할 경우 명시적으로 지정된 index를 사용
#   - 같은 타입의 0개 이상의 데이터를 가질 수 있음
#   * data로만 생성하기
#  - index는 기본적으로 0부터 자동적으로 생성

# %%
s1 = pd.Series([1,2,3])   #파이썬 enumerate 느낌
s1
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
s2 = pd.Series(['a','b','c'])
s2
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
s3 =pd.Series(np.arange(200))
s3
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4
#       ...
# 195    195
# 196    196
# 197    197
# 198    198
# 199    199
# Length: 200, dtype: int64

# %%
s4 = pd.Series([1, 2, 3], ['a', 'b', 'c'])
s4
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
s5 = pd.Series(np.arange(5), np.arange(100, 105), dtype=np.int16)
s5
# Out:
# 100    0
# 101    1
# 102    2
# 103    3
# 104    4
# dtype: int16

# %%
s5.index
# Out:
# Int64Index([100, 101, 102, 103, 104], dtype='int64')

# %%
s5.values
# Out:
# array([0, 1, 2, 3, 4], dtype=int16)

# %% [markdown]
# #### **Series size, shape, unique, count, value_counts 함수**
#  - size : 개수 반환
#  - shape : 튜플형태로 shape반환
#  - unique: 유일한 값만 ndarray로 반환
#  - count : NaN을 제외한 개수를 반환
#  - mean: NaN을 제외한 평균
#  - value_counts: NaN을 제외하고 각 값들의 빈도를 반환

# %%
s = pd.Series([1, 1, 2, 1, 2, 2, 2, 1, 1, 3, 3, 4, 5, 5, 7, np.NaN])
s
# Out:
# 0     1.0
# 1     1.0
# 2     2.0
# 3     1.0
# 4     2.0
# 5     2.0
# 6     2.0
# 7     1.0
# 8     1.0
# 9     3.0
# 10    3.0
# 11    4.0
# 12    5.0
# 13    5.0
# 14    7.0
# 15    NaN
# dtype: float64

# %%
len(s)
# Out:
# 16

# %%
s.size
# Out:
# 16

# %%
s.shape
# Out:
# (16,)

# %%
s.unique()
# Out:
# array([ 1.,  2.,  3.,  4.,  5.,  7., nan])

# %%
s.count()
# Out:
# 15

# %%
s.mean()
# Out:
# 2.6666666666666665

# %%
s.value_counts()
# Out:
# 1.0    5
# 2.0    4
# 3.0    2
# 5.0    2
# 7.0    1
# 4.0    1
# dtype: int64

# %%
s[[5, 7, 8, 10]].value_counts()
# Out:
# 1.0    2
# 3.0    1
# 2.0    1
# dtype: int64

# %% [markdown]
# #### **Series 값 변경**
#   - 추가 및 업데이트: 인덱스를 이용
#   - 삭제: drop함수 이용

# %%
s = pd.Series(np.arange(100, 105), ['a', 'b', 'c', 'd', 'e'])
s
# Out:
# a    100
# b    101
# c    102
# d    103
# e    104
# dtype: int64

# %%
s.drop('a',inplace=True)

# %%
s
# Out:
# b    101
# c    102
# d    103
# e    104
# dtype: int64

# %%
train_data = pd.read_csv('/Users/leejunseung/Desktop/머신러닝과 데이터분석 강의자료/Part 01~04) Python/04. 데이터 분석을 위한 Python (Pandas)/data/train.csv')

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# #### dataframe 데이터 파악하기
#  - shape 속성 (row, column)
#  - describe 함수 - 숫자형 데이터의 통계치 계산
#  - info 함수 - 데이터 타입, 각 아이템의 개수 등 출력

# %%
train_data.shape
# Out:
# (891, 12)

# %%
train_data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train_data.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
train_data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# #### DataFrame 생성하기

# %%
data = {'a' : 100, 'b' : 200, 'c' : 300}
pd.DataFrame(data, index=['x', 'y', 'z'])
# Out:
#      a    b    c
# x  100  200  300
# y  100  200  300
# z  100  200  300

# %%
a = pd.Series([100, 200, 300], ['a', 'b', 'd'])
b = pd.Series([101, 201, 301], ['a', 'b', 'k'])
c = pd.Series([110, 210, 310], ['a', 'b', 'c'])

pd.DataFrame([a, b, c], index=[100, 101, 102])
# Out:
#          a      b      d      k      c
# 100  100.0  200.0  300.0    NaN    NaN
# 101  101.0  201.0    NaN  301.0    NaN
# 102  110.0  210.0    NaN    NaN  310.0

# %% [markdown]
# #### read_csv 함수 파라미터
#  - sep - 각 데이터 값을 구별하기 위한 구분자(separator) 설정
#  - header - header를 무시할 경우, None 설정
#  - index_col - index로 사용할 column 설정
#  - usecols - 실제로 dataframe에 로딩할 columns만 설정

# %%
train_data = pd.read_csv('/Users/leejunseung/Desktop/머신러닝과 데이터분석 강의자료/Part 01~04) Python/04. 데이터 분석을 위한 Python (Pandas)/data/train.csv', index_col='PassengerId', usecols=['PassengerId', 'Survived', 'Pclass', 'Name'])
train_data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name
# PassengerId
# 1                                      Braund, Mr. Owen Harris
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                       Heikkinen, Miss. Laina
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                                     Allen, Mr. William Henry
# ...                                                        ...
# 887                                      Montvila, Rev. Juozas
# ...

# %% [markdown]
# #### dataframe slicing
#   - dataframe의 경우 기본적으로 [] 연산자가 **column 선택**에 사용
#   - 하지만, slicing은 row 레벨로 지원

# %%
train_data[7:10]
# Out:
#              Survived  Pclass  \
# PassengerId
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name
# PassengerId
# 8                               Palsson, Master. Gosta Leonard
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                         Nasser, Mrs. Nicholas (Adele Achem)

# %% [markdown]
# #### row 선택하기
#   - Seires의 경우 []로 row 선택이 가능하나, **DataFrame의 경우는 기본적으로 column을 선택하도록 설계**
#   - **.loc, .iloc**로 row 선택 가능
#     - loc - 인덱스 자체를 사용
#     - iloc - 0 based index로 사용
#     - 이 두 함수는 ,를 사용하여 column 선택도 가능

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
# dtypes: int64(2), object(1)
# memory usage: 27.8+ KB

# %%
train_data.tail()
# Out:
#      Survived  Pclass                                      Name
# 986         0       2                     Montvila, Rev. Juozas
# 987         1       1              Graham, Miss. Margaret Edith
# 988         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 989         1       1                     Behr, Mr. Karl Howell
# 990         0       3                       Dooley, Mr. Patrick

# %%
train_data.loc[986]
# Out:
# Survived                        0
# Pclass                          2
# Name        Montvila, Rev. Juozas
# Name: 986, dtype: object

# %%
train_data.iloc[[0, 100, 200, 2]]
# Out:
#      Survived  Pclass                            Name
# 100         0       3         Braund, Mr. Owen Harris
# 200         0       3         Petranec, Miss. Matilda
# 300         0       3  Vande Walle, Mr. Nestor Cyriel
# 102         1       3          Heikkinen, Miss. Laina

# %%
train_data.head()
# Out:
#      Survived  Pclass                                               Name
# 100         0       3                            Braund, Mr. Owen Harris
# 101         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 102         1       3                             Heikkinen, Miss. Laina
# 103         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 104         0       3                           Allen, Mr. William Henry

# %% [markdown]
# #### **boolean selection으로 row 선택하기**
#  - numpy에서와 동일한 방식으로 해당 조건에 맞는 row만 선택

# %%
train_data = pd.read_csv('/Users/leejunseung/Desktop/머신러닝과 데이터분석 강의자료/Part 01~04) Python/04. 데이터 분석을 위한 Python (Pandas)/data/train.csv')
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
class_ = train_data['Pclass'] ==1 
age_ = (train_data['Age']>=30)&(train_data['Age']<40)

train_data[class_&age_]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 61            62         1       1
# 137          138         0       1
# 215          216         1       1
# 218          219         1       1
# 224          225         1       1
# 230          231         1       1
# 248          249         1       1
# 257          258         1       1
# 258          259         1       1
# 269          270         1       1
# 273          274         0       1
# 309          310         1       1
# 318          319         1       1
# 325          326         1       1
# 332          333         0       1
# 383          384         1       1
# 390          391         1       1
# 412          413         1       1
# 447          448         1       1
# 452          453         0       1
# 486          487         1       1
# 512          513         1       1
# 520          521         1       1
# ...

# %% [markdown]
# #### 새 column 추가하기
#  - [] 사용하여 추가하기
#  - insert 함수 사용하여 원하는 위치에 추가하기

# %%
train_data['Age_double'] = train_data['Age'] * 2
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_double
# 0      0         A/5 21171   7.2500   NaN        S        44.0
# 1      0          PC 17599  71.2833   C85        C        76.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S        52.0
# ...

# %%
train_data.insert(3, 'Fare10', train_data['Fare'] / 10)
train_data.head()
# Out:
#    PassengerId  Survived  Pclass   Fare10  \
# 0            1         0       3  0.72500
# 1            2         1       1  7.12833
# 2            3         1       3  0.79250
# 3            4         1       1  5.31000
# 4            5         0       3  0.80500
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_double
# 0      0         A/5 21171   7.2500   NaN        S        44.0
# 1      0          PC 17599  71.2833   C85        C        76.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S        52.0
# ...

# %%
#column 삭제
train_data.drop('Age_double',axis=1)
train_data.head()
# Out:
#    PassengerId  Survived  Pclass   Fare10  \
# 0            1         0       3  0.72500
# 1            2         1       1  7.12833
# 2            3         1       3  0.79250
# 3            4         1       1  5.31000
# 4            5         0       3  0.80500
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Age_double
# 0      0         A/5 21171   7.2500   NaN        S        44.0
# 1      0          PC 17599  71.2833   C85        C        76.0
# 2      0  STON/O2. 3101282   7.9250   NaN        S        52.0
# ...

# %%
train_data.drop('Age_double',axis=1,inplace=True)
train_data.head()
# Out:
#    PassengerId  Survived  Pclass   Fare10  \
# 0            1         0       3  0.72500
# 1            2         1       1  7.12833
# 2            3         1       3  0.79250
# 3            4         1       1  5.31000
# 4            5         0       3  0.80500
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %% [markdown]
# #### NaN 값 확인
#  - info함수를 통하여 개수 확인
#  - isna함수를 통해 boolean 타입으로 확인

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Fare10       891 non-null    float64
#  4   Name         891 non-null    object
#  5   Sex          891 non-null    object
#  6   Age          714 non-null    float64
#  7   SibSp        891 non-null    int64
#  8   Parch        891 non-null    int64
#  9   Ticket       891 non-null    object
#  10  Fare         891 non-null    float64
#  11  Cabin        204 non-null    object
#  12  Embarked     889 non-null    object
#  13  Age_double   714 non-null    float64
# dtypes: float64(4), int64(5), object(5)
# memory usage: 97.6+ KB

# %%
train_data.isna()
# Out:
#      PassengerId  Survived  Pclass  Fare10   Name    Sex    Age  SibSp  Parch  \
# 0          False     False   False   False  False  False  False  False  False
# 1          False     False   False   False  False  False  False  False  False
# 2          False     False   False   False  False  False  False  False  False
# 3          False     False   False   False  False  False  False  False  False
# 4          False     False   False   False  False  False  False  False  False
# ..           ...       ...     ...     ...    ...    ...    ...    ...    ...
# 886        False     False   False   False  False  False  False  False  False
# 887        False     False   False   False  False  False  False  False  False
# 888        False     False   False   False  False  False   True  False  False
# 889        False     False   False   False  False  False  False  False  False
# 890        False     False   False   False  False  False  False  False  False
#
# ...

# %% [markdown]
# #### NaN 처리 방법
#  - 데이터에서 삭제
#    - dropna 함수
#  - 다른 값으로 치환
#    - fillna 함수

# %%
train_data.dropna()
# Out:
#      PassengerId  Survived  Pclass   Fare10  \
# 1              2         1       1  7.12833
# 3              4         1       1  5.31000
# 6              7         0       1  5.18625
# 10            11         1       3  1.67000
# 11            12         1       1  2.65500
# ..           ...       ...     ...      ...
# 871          872         1       1  5.25542
# 872          873         0       1  0.50000
# 879          880         1       1  8.31583
# 887          888         1       1  3.00000
# 889          890         1       1  3.00000
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# ...

# %%
train_data.dropna(subset=['Age', 'Cabin']) #특정 column
# Out:
#      PassengerId  Survived  Pclass   Fare10  \
# 1              2         1       1  7.12833
# 3              4         1       1  5.31000
# 6              7         0       1  5.18625
# 10            11         1       3  1.67000
# 11            12         1       1  2.65500
# ..           ...       ...     ...      ...
# 871          872         1       1  5.25542
# 872          873         0       1  0.50000
# 879          880         1       1  8.31583
# 887          888         1       1  3.00000
# 889          890         1       1  3.00000
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# ...

# %%
train_data.dropna(axis=1) #축기준으로 drop
# Out:
#      PassengerId  Survived  Pclass   Fare10  \
# 0              1         0       3  0.72500
# 1              2         1       1  7.12833
# 2              3         1       3  0.79250
# 3              4         1       1  5.31000
# 4              5         0       3  0.80500
# ..           ...       ...     ...      ...
# 886          887         0       2  1.30000
# 887          888         1       1  3.00000
# 888          889         0       3  2.34500
# 889          890         1       1  3.00000
# 890          891         0       3  0.77500
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# ...

# %% [markdown]
# * NaN 값 대체하기
#  - 평균으로 대체하기
#  - 생존자/사망자 별 평균으로 대체하기

# %%
train_data['Age'].fillna(train_data['Age'].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
#생존자 나이 평균
mean1 = train_data[train_data['Survived']==1]['Age'].mean()
#사망자 나이 평균
mean2 = train_data[train_data['Survived']==0]['Age'].mean()

print(mean1,mean2)
# Out:
# 28.343689655172415 30.62617924528302

# %%
#생존자 등급 평균
mean3 = train_data[train_data['Survived']==1]['Pclass'].mean()
#사망자 등급 평균
mean4 = train_data[train_data['Survived']==0]['Pclass'].mean()

print(mean3,mean4)
# Out:
# 1.9502923976608186 2.5318761384335153

# %%
train_data[train_data['Survived'] == 1]['Age'].fillna(mean1)
train_data[train_data['Survived'] == 0]['Age'].fillna(mean2)
# Out:
# 0      22.000000
# 4      35.000000
# 5       2.531876
# 6      54.000000
# 7       2.000000
#          ...
# 884    25.000000
# 885    39.000000
# 886    27.000000
# 888     2.531876
# 890    32.000000
# Name: Age, Length: 549, dtype: float64

# %% [markdown]
# #### One-hot encoding (데이터 전처리)
#  - 범주형 데이터는 분석단계에서 계산이 어렵기 때문에 숫자형으로 변경이 필요함
#  - 범주형 데이터의 각 범주(category)를 column레벨로 변경
#  - 해당 범주에 해당하면 1, 아니면 0으로 채우는 인코딩 기법
#  - pandas.get_dummies 함수 사용
#    - drop_first : 첫번째 카테고리 값은 사용하지 않음

# %%
pd.get_dummies(train_data,columns=['Pclass','Sex','Embarked'],drop_first=False)
# Out:
#      PassengerId  Survived   Fare10  \
# 0              1         0  0.72500
# 1              2         1  7.12833
# 2              3         1  0.79250
# 3              4         1  5.31000
# 4              5         0  0.80500
# ..           ...       ...      ...
# 886          887         0  1.30000
# 887          888         1  3.00000
# 888          889         0  2.34500
# 889          890         1  3.00000
# 890          891         0  0.77500
#
#                                                   Name        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.000000      1
# 2                               Heikkinen, Miss. Laina  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.000000      1
# 4                             Allen, Mr. William Henry  35.000000      0
# ..                                                 ...        ...    ...
# ...

# %%
pd.get_dummies(train_data, columns=['Pclass', 'Sex', 'Embarked'], drop_first=True)
# Out:
#      PassengerId  Survived   Fare10  \
# 0              1         0  0.72500
# 1              2         1  7.12833
# 2              3         1  0.79250
# 3              4         1  5.31000
# 4              5         0  0.80500
# ..           ...       ...      ...
# 886          887         0  1.30000
# 887          888         1  3.00000
# 888          889         0  2.34500
# 889          890         1  3.00000
# 890          891         0  0.77500
#
#                                                   Name        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.000000      1
# 2                               Heikkinen, Miss. Laina  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.000000      1
# 4                             Allen, Mr. William Henry  35.000000      0
# ..                                                 ...        ...    ...
# ...

# %% [markdown]
# #### group by
#   + 아래의 세 단계를 적용하여 데이터를 그룹화(groupping) (SQL의 group by 와 개념적으로는 동일, 사용법은 유사)\https://brunch.co.kr/@dan-kim/18
#     - 데이터 분할
#     - operation 적용
#     - 데이터 병합

# %%
train_data = pd.read_csv('/Users/leejunseung/Desktop/머신러닝과 데이터분석 강의자료/Part 01~04) Python/04. 데이터 분석을 위한 Python (Pandas)/data/train.csv')
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
class_group = train_data.groupby('Pclass')
class_group

# %%
class_group.groups
# Out:
# {1: [1, 3, 6, 11, 23, 27, 30, 31, 34, 35, 52, 54, 55, 61, 62, 64, 83, 88, 92, 96, 97, 102, 110, 118, 124, 136, 137, 139, 151, 155, 166, 168, 170, 174, 177, 185, 187, 194, 195, 209, 215, 218, 224, 230, 245, 248, 252, 256, 257, 258, 262, 263, 268, 269, 270, 273, 275, 284, 290, 291, 295, 297, 298, 299, 305, 306, 307, 309, 310, 311, 318, 319, 325, 329, 331, 332, 334, 336, 337, 339, 341, 351, 356, 366, 369, 370, 373, 375, 377, 380, 383, 390, 393, 412, 430, 434, 435, 438, 445, 447, ...], 2: [9, 15, 17, 20, 21, 33, 41, 43, 53, 56, 58, 66, 70, 72, 78, 84, 98, 99, 117, 120, 122, 123, 133, 134, 135, 144, 145, 148, 149, 150, 161, 178, 181, 183, 190, 191, 193, 199, 211, 213, 217, 219, 221, 226, 228, 232, 234, 236, 237, 238, 239, 242, 247, 249, 259, 265, 272, 277, 288, 292, 303, 308, 312, 314, 316, 317, 322, 323, 327, 340, 342, 343, 344, 345, 346, 357, 361, 385, 387, 389, 397, 398, 399, 405, 407, 413, 416, 417, 418, 426, 427, 432, 437, 439, 440, 443, 446, 450, 458, 463, ...], 3: [0, 2, 4, 5, 7, 8
# ...

# %%
gender_group = train_data.groupby('Sex')
gender_group.groups
# Out:
# {'female': [1, 2, 3, 8, 9, 10, 11, 14, 15, 18, 19, 22, 24, 25, 28, 31, 32, 38, 39, 40, 41, 43, 44, 47, 49, 52, 53, 56, 58, 61, 66, 68, 71, 79, 82, 84, 85, 88, 98, 100, 106, 109, 111, 113, 114, 119, 123, 128, 132, 133, 136, 140, 141, 142, 147, 151, 156, 161, 166, 167, 172, 177, 180, 184, 186, 190, 192, 194, 195, 198, 199, 205, 208, 211, 215, 216, 218, 229, 230, 233, 235, 237, 240, 241, 246, 247, 251, 254, 255, 256, 257, 258, 259, 264, 268, 269, 272, 274, 275, 276, ...], 'male': [0, 4, 5, 6, 7, 12, 13, 16, 17, 20, 21, 23, 26, 27, 29, 30, 33, 34, 35, 36, 37, 42, 45, 46, 48, 50, 51, 54, 55, 57, 59, 60, 62, 63, 64, 65, 67, 69, 70, 72, 73, 74, 75, 76, 77, 78, 80, 81, 83, 86, 87, 89, 90, 91, 92, 93, 94, 95, 96, 97, 99, 101, 102, 103, 104, 105, 107, 108, 110, 112, 115, 116, 117, 118, 120, 121, 122, 124, 125, 126, 127, 129, 130, 131, 134, 135, 137, 138, 139, 143, 144, 145, 146, 148, 149, 150, 152, 153, 154, 155, ...]}

# %% [markdown]
# #### groupping 함수
#  - 그룹 데이터에 적용 가능한 통계 함수(NaN은 제외하여 연산)
#  - count - 데이터 개수
#  - sum   - 데이터의 합
#  - mean, std, var - 평균, 표준편차, 분산
#  - min, max - 최소, 최대값

# %%
class_group.count()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked
# Pclass
# 1         176       214
# 2          16       184
# 3          12       491

# %%
class_group.mean()['Survived']
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %% [markdown]
# #### 복수 columns로 groupping 하기
#  - groupby에 column 리스트를 전달
#  - 통계함수를 적용한 결과는 multiindex를 갖는 dataframe

# %%
train_data.groupby(['Pclass','Sex']).mean()
# Out:
#                PassengerId  Survived        Age     SibSp     Parch  \
# Pclass Sex
# 1      female   469.212766  0.968085  34.611765  0.553191  0.457447
#        male     455.729508  0.368852  41.281386  0.311475  0.278689
# 2      female   443.105263  0.921053  28.722973  0.486842  0.605263
#        male     447.962963  0.157407  30.740707  0.342593  0.222222
# 3      female   399.729167  0.500000  21.750000  0.895833  0.798611
#        male     455.515850  0.135447  26.507589  0.498559  0.224784
#
#                      Fare
# Pclass Sex
# 1      female  106.125798
#        male     67.226127
# 2      female   21.970121
#        male     19.741782
# 3      female   16.118810
#        male     12.661633

# %%
train_data.groupby(['Pclass', 'Sex']).mean().loc[(2, 'female')]
# Out:
# PassengerId    443.105263
# Survived         0.921053
# Age             28.722973
# SibSp            0.486842
# Parch            0.605263
# Fare            21.970121
# Name: (2, female), dtype: float64

# %%
train_data.groupby(['Pclass', 'Sex']).mean().index
# Out:
# MultiIndex([(1, 'female'),
#             (1,   'male'),
#             (2, 'female'),
#             (2,   'male'),
#             (3, 'female'),
#             (3,   'male')],
#            names=['Pclass', 'Sex'])

# %% [markdown]
# #### index를 이용한 group by
#  - index가 있는 경우, groupby 함수에 level 사용 가능
#    - level은 index의 depth를 의미하며, 가장 왼쪽부터 0부터 증가

# %% [markdown]
# * **set_index** 함수
#  - column 데이터를 index 레벨로 변경
# * **reset_index** 함수
#  - 인덱스 초기화

# %%
train_data.set_index(['Pclass', 'Sex']).reset_index()
# Out:
#      Pclass     Sex  PassengerId  Survived  \
# 0         3    male            1         0
# 1         1  female            2         1
# 2         3  female            3         1
# 3         1  female            4         1
# 4         3    male            5         0
# ..      ...     ...          ...       ...
# 886       2    male          887         0
# 887       1  female          888         1
# 888       3  female          889         0
# 889       1    male          890         1
# 890       3    male          891         0
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# ...

# %%
train_data.set_index('Age').groupby(level=0).mean()
# Out:
#        PassengerId  Survived  Pclass  SibSp  Parch      Fare
# Age
# 0.42         804.0       1.0     3.0    0.0    1.0    8.5167
# 0.67         756.0       1.0     2.0    1.0    1.0   14.5000
# 0.75         557.5       1.0     3.0    2.0    1.0   19.2583
# 0.83         455.5       1.0     2.0    0.5    1.5   23.8750
# 0.92         306.0       1.0     1.0    1.0    2.0  151.5500
# ...            ...       ...     ...    ...    ...       ...
# 70.00        709.5       0.0     1.5    0.5    0.5   40.7500
# 70.50        117.0       0.0     3.0    0.0    0.0    7.7500
# 71.00        295.5       0.0     1.0    0.0    0.0   42.0792
# 74.00        852.0       0.0     3.0    0.0    0.0    7.7750
# 80.00        631.0       1.0     1.0    0.0    0.0   30.0000
#
# [88 rows x 6 columns]

# %% [markdown]
# #### transform 함수
#  - groupby 후 transform 함수를 사용하면 원래의 index를 유지한 상태로 통계함수를 적용
#  - 전체 데이터의 집계가 아닌 각 그룹에서의 집계를 계산
#  - 따라서 새로 생성된 데이터를 원본 dataframe과 합치기 쉬움

# %%
train_data.groupby('Pclass').mean()
# Out:
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2        445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 3        439.154786  0.242363  25.140620  0.615071  0.393075  13.675550

# %%
train_data.groupby('Pclass').transform(np.mean)
# Out:
#      PassengerId  Survived        Age     SibSp     Parch       Fare
# 0     439.154786  0.242363  25.140620  0.615071  0.393075  13.675550
# 1     461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 2     439.154786  0.242363  25.140620  0.615071  0.393075  13.675550
# 3     461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 4     439.154786  0.242363  25.140620  0.615071  0.393075  13.675550
# ..           ...       ...        ...       ...       ...        ...
# 886   445.956522  0.472826  29.877630  0.402174  0.380435  20.662183
# 887   461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 888   439.154786  0.242363  25.140620  0.615071  0.393075  13.675550
# 889   461.597222  0.629630  38.233441  0.416667  0.356481  84.154687
# 890   439.154786  0.242363  25.140620  0.615071  0.393075  13.675550
#
# [891 rows x 6 columns]

# %%
train_data['Age2'] = train_data.groupby('Pclass').transform(np.mean)['Age']
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_data['Age3'] = train_data.groupby(['Pclass', 'Sex']).transform(np.mean)['Age']
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### pivot
#  - dataframe의 형태를 변경
#  - 인덱스, 컬럼, 데이터로 사용할 컬럼을 명시

# %%
data = pd.DataFrame({
    '지역': ['서울', '서울', '서울', '경기', '경기', '부산', '서울', '서울', '부산', '경기', '경기', '경기'],
    '요일': ['월요일', '화요일', '수요일', '월요일', '화요일', '월요일', '목요일', '금요일', '화요일', '수요일', '목요일', '금요일'],
    '강수량': [100, 80, 1000, 200, 200, 100, 50, 100, 200, 100, 50, 100],
    '강수확률': [80, 70, 90, 10, 20, 30, 50, 90, 20, 80, 50, 10]
                  })

data
# Out:
#     지역   요일   강수량  강수확률
# 0   서울  월요일   100    80
# 1   서울  화요일    80    70
# 2   서울  수요일  1000    90
# 3   경기  월요일   200    10
# 4   경기  화요일   200    20
# 5   부산  월요일   100    30
# 6   서울  목요일    50    50
# 7   서울  금요일   100    90
# 8   부산  화요일   200    20
# 9   경기  수요일   100    80
# 10  경기  목요일    50    50
# 11  경기  금요일   100    10

# %%
data.pivot('지역', '요일')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-5443f2c364ac> in <module>
# ----> 1 data.pivot('지역', '요일')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    6877         from pandas.core.reshape.pivot import pivot
#    6878
# -> 6879         return pivot(self, index=index, columns=columns, values=values)
#    6880
#    6881     _shared_docs[
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     459         else:
#     460             indexed = data._constructor_sliced(data[values]._values, index=index)
# --> 461     return indexed.unstack(columns)
#     462
#     463
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in unstack(self, level, fill_value)
# ...

# %% [markdown]
# #### pivot_table
#  - 기능적으로 pivot과 동일
#  - pivot과의 차이점
#    - 중복되는 모호한 값이 있을 경우, aggregation 함수 사용하여 값을 채움

# %%
pd.pivot_table(data, index='요일', columns='지역', aggfunc=np.mean)
# Out:
#        강수량                 강수확률
# 지역      경기     부산      서울    경기    부산    서울
# 요일
# 금요일  100.0    NaN   100.0  10.0   NaN  90.0
# 목요일   50.0    NaN    50.0  50.0   NaN  50.0
# 수요일  100.0    NaN  1000.0  80.0   NaN  90.0
# 월요일  200.0  100.0    90.0  10.0  30.0  75.0
# 화요일  200.0  200.0     NaN  20.0  20.0   NaN

# %% [markdown]
# #### concat 함수 사용하여 dataframe 병합하기
#  - pandas.concat 함수
#  - 축을 따라 dataframe을 병합 가능
#    - 기본 axis = 0 -> 행단위 병합

# %%
df1 = pd.DataFrame({'key1' : np.arange(10), 'value1' : np.random.randn(10)})
df1
# Out:
#    key1    value1
# 0     0  0.326659
# 1     1 -1.132359
# 2     2  1.491938
# 3     3 -0.369853
# 4     4 -3.850132
# 5     5 -2.758834
# 6     6  1.400870
# 7     7  0.240634
# 8     8  0.785185
# 9     9 -0.625657

# %%
df2 = pd.DataFrame({'key1' : np.arange(10), 'value1' : np.random.randn(10)})
df2
# Out:
#    key1    value1
# 0     0 -1.043584
# 1     1 -0.411220
# 2     2 -0.076758
# 3     3  1.634743
# 4     4 -0.517501
# 5     5 -0.136412
# 6     6  0.042362
# 7     7  0.553526
# 8     8 -0.627081
# 9     9 -0.953720

# %%
pd.concat([df1, df2]) #ignore_index=True
# Out:
#    key1    value1
# 0     0  0.326659
# 1     1 -1.132359
# 2     2  1.491938
# 3     3 -0.369853
# 4     4 -3.850132
# 5     5 -2.758834
# 6     6  1.400870
# 7     7  0.240634
# 8     8  0.785185
# 9     9 -0.625657
# 0     0 -1.043584
# 1     1 -0.411220
# 2     2 -0.076758
# 3     3  1.634743
# 4     4 -0.517501
# 5     5 -0.136412
# 6     6  0.042362
# 7     7  0.553526
# 8     8 -0.627081
# 9     9 -0.953720

# %%
pd.concat([df1, df2], axis=1)
# Out:
#    key1    value1  key1    value1
# 0     0  0.326659     0 -1.043584
# 1     1 -1.132359     1 -0.411220
# 2     2  1.491938     2 -0.076758
# 3     3 -0.369853     3  1.634743
# 4     4 -3.850132     4 -0.517501
# 5     5 -2.758834     5 -0.136412
# 6     6  1.400870     6  0.042362
# 7     7  0.240634     7  0.553526
# 8     8  0.785185     8 -0.627081
# 9     9 -0.625657     9 -0.953720

# %% [markdown]
# column 명이 다른 경우

# %%
df3 = pd.DataFrame({'key2' : np.arange(10), 'value2' : np.random.randn(10)})
df3
# Out:
#    key2    value2
# 0     0 -2.944190
# 1     1  0.815074
# 2     2 -0.119653
# 3     3 -0.292949
# 4     4  0.825106
# 5     5 -0.499958
# 6     6 -0.171332
# 7     7 -0.529360
# 8     8  0.414134
# 9     9  0.894602

# %%
pd.concat([df1, df3])
# Out:
#    key1    value1  key2    value2
# 0   0.0  0.326659   NaN       NaN
# 1   1.0 -1.132359   NaN       NaN
# 2   2.0  1.491938   NaN       NaN
# 3   3.0 -0.369853   NaN       NaN
# 4   4.0 -3.850132   NaN       NaN
# 5   5.0 -2.758834   NaN       NaN
# 6   6.0  1.400870   NaN       NaN
# 7   7.0  0.240634   NaN       NaN
# 8   8.0  0.785185   NaN       NaN
# 9   9.0 -0.625657   NaN       NaN
# 0   NaN       NaN   0.0 -2.944190
# 1   NaN       NaN   1.0  0.815074
# 2   NaN       NaN   2.0 -0.119653
# 3   NaN       NaN   3.0 -0.292949
# 4   NaN       NaN   4.0  0.825106
# 5   NaN       NaN   5.0 -0.499958
# 6   NaN       NaN   6.0 -0.171332
# 7   NaN       NaN   7.0 -0.529360
# 8   NaN       NaN   8.0  0.414134
# 9   NaN       NaN   9.0  0.894602

# %% [markdown]
# #### dataframe merge
#  - SQL의 join처럼 특정한 column을 기준으로 병합
#    - join 방식: how 파라미터를 통해 명시
#      - inner: 기본값, 일치하는 값이 있는 경우
#      - left: left outer join
#      - right: right outer join
#      - outer: full outer join
#
#  - pandas.merge 함수가 사용됨

# %%
customer = pd.DataFrame({'customer_id' : np.arange(6), 
                    'name' : ['철수'"", '영희', '길동', '영수', '수민', '동건'], 
                    '나이' : [40, 20, 21, 30, 31, 18]})

customer
# Out:
#    customer_id name  나이
# 0            0   철수  40
# 1            1   영희  20
# 2            2   길동  21
# 3            3   영수  30
# 4            4   수민  31
# 5            5   동건  18

# %%
orders = pd.DataFrame({'customer_id' : [1, 1, 2, 2, 2, 3, 3, 1, 4, 9], 
                    'item' : ['치약', '칫솔', '이어폰', '헤드셋', '수건', '생수', '수건', '치약', '생수', '케이스'], 
                    'quantity' : [1, 2, 1, 1, 3, 2, 2, 3, 2, 1]})
orders
# Out:
#    customer_id item  quantity
# 0            1   치약         1
# 1            1   칫솔         2
# 2            2  이어폰         1
# 3            2  헤드셋         1
# 4            2   수건         3
# 5            3   생수         2
# 6            3   수건         2
# 7            1   치약         3
# 8            4   생수         2
# 9            9  케이스         1

# %% [markdown]
# * on
#  - join 대상이 되는 column 명시

# %%
pd.merge(customer,orders,on='customer_id',how='inner')
# Out:
#    customer_id name  나이 item  quantity
# 0            1   영희  20   치약         1
# 1            1   영희  20   칫솔         2
# 2            1   영희  20   치약         3
# 3            2   길동  21  이어폰         1
# 4            2   길동  21  헤드셋         1
# 5            2   길동  21   수건         3
# 6            3   영수  30   생수         2
# 7            3   영수  30   수건         2
# 8            4   수민  31   생수         2

# %%
pd.merge(customer, orders, on='customer_id', how='left')#customer 기준
# Out:
#     customer_id name  나이 item  quantity
# 0             0   철수  40  NaN       NaN
# 1             1   영희  20   치약       1.0
# 2             1   영희  20   칫솔       2.0
# 3             1   영희  20   치약       3.0
# 4             2   길동  21  이어폰       1.0
# 5             2   길동  21  헤드셋       1.0
# 6             2   길동  21   수건       3.0
# 7             3   영수  30   생수       2.0
# 8             3   영수  30   수건       2.0
# 9             4   수민  31   생수       2.0
# 10            5   동건  18  NaN       NaN

# %%
pd.merge(customer, orders, on='customer_id', how='right')#orders 기준
# Out:
#    customer_id name    나이 item  quantity
# 0            1   영희  20.0   치약         1
# 1            1   영희  20.0   칫솔         2
# 2            2   길동  21.0  이어폰         1
# 3            2   길동  21.0  헤드셋         1
# 4            2   길동  21.0   수건         3
# 5            3   영수  30.0   생수         2
# 6            3   영수  30.0   수건         2
# 7            1   영희  20.0   치약         3
# 8            4   수민  31.0   생수         2
# 9            9  NaN   NaN  케이스         1

# %%
pd.merge(customer, orders, on='customer_id', how='outer')#합침
# Out:
#     customer_id name    나이 item  quantity
# 0             0   철수  40.0  NaN       NaN
# 1             1   영희  20.0   치약       1.0
# 2             1   영희  20.0   칫솔       2.0
# 3             1   영희  20.0   치약       3.0
# 4             2   길동  21.0  이어폰       1.0
# 5             2   길동  21.0  헤드셋       1.0
# 6             2   길동  21.0   수건       3.0
# 7             3   영수  30.0   생수       2.0
# 8             3   영수  30.0   수건       2.0
# 9             4   수민  31.0   생수       2.0
# 10            5   동건  18.0  NaN       NaN
# 11            9  NaN   NaN  케이스       1.0

# %% [markdown]
# #### 연습문제
# 1. 가장 많이 팔린 아이템은?
# 2. 영희가 가장 많이 구매한 아이템은?

# %%
pd.merge(customer,orders,on='customer_id')
# Out:
#    customer_id name  나이 item  quantity
# 0            1   영희  20   치약         1
# 1            1   영희  20   칫솔         2
# 2            1   영희  20   치약         3
# 3            2   길동  21  이어폰         1
# 4            2   길동  21  헤드셋         1
# 5            2   길동  21   수건         3
# 6            3   영수  30   생수         2
# 7            3   영수  30   수건         2
# 8            4   수민  31   생수         2

# %%
pd.merge(customer,orders,on='customer_id').groupby('item').sum()
# Out:
#       customer_id  나이  quantity
# item
# 생수              7  61         4
# 수건              5  51         5
# 이어폰             2  21         1
# 치약              2  40         4
# 칫솔              1  20         2
# 헤드셋             2  21         1

# %%
pd.merge(customer,orders,on='customer_id').groupby('item').sum().sort_values(by='quantity',ascending=False)
# Out:
#       customer_id  나이  quantity
# item
# 수건              5  51         5
# 생수              7  61         4
# 치약              2  40         4
# 칫솔              1  20         2
# 이어폰             2  21         1
# 헤드셋             2  21         1

# %%
pd.merge(customer,orders,on='customer_id')
# Out:
#    customer_id name  나이 item  quantity
# 0            1   영희  20   치약         1
# 1            1   영희  20   칫솔         2
# 2            1   영희  20   치약         3
# 3            2   길동  21  이어폰         1
# 4            2   길동  21  헤드셋         1
# 5            2   길동  21   수건         3
# 6            3   영수  30   생수         2
# 7            3   영수  30   수건         2
# 8            4   수민  31   생수         2

# %%
pd.merge(customer,orders,on='customer_id').groupby(['name','item']).sum()
# Out:
#            customer_id  나이  quantity
# name item
# 길동   수건              2  21         3
#      이어폰             2  21         1
#      헤드셋             2  21         1
# 수민   생수              4  31         2
# 영수   생수              3  30         2
#      수건              3  30         2
# 영희   치약              2  40         4
#      칫솔              1  20         2

# %%
pd.merge(customer,orders,on='customer_id').groupby(['name','item']).sum().loc['영희','quantity']
# Out:
# item
# 치약    4
# 칫솔    2
# Name: quantity, dtype: int64

# %% [markdown]
# #### join 함수
#  - 내부적으로 pandas.merge 함수 사용
#  - 기본적으로 index를 사용하여 left join

# %%
cust1 = customer.set_index('customer_id')
cust1
# Out:
#             name  나이
# customer_id
# 0             철수  40
# 1             영희  20
# 2             길동  21
# 3             영수  30
# 4             수민  31
# 5             동건  18

# %%
order1 = orders.set_index('customer_id')
order1
# Out:
#             item  quantity
# customer_id
# 1             치약         1
# 1             칫솔         2
# 2            이어폰         1
# 2            헤드셋         1
# 2             수건         3
# 3             생수         2
# 3             수건         2
# 1             치약         3
# 4             생수         2
# 9            케이스         1

# %%
cust1.join(order1, how='inner')
# Out:
#             name  나이 item  quantity
# customer_id
# 1             영희  20   치약         1
# 1             영희  20   칫솔         2
# 1             영희  20   치약         3
# 2             길동  21  이어폰         1
# 2             길동  21  헤드셋         1
# 2             길동  21   수건         3
# 3             영수  30   생수         2
# 3             영수  30   수건         2
# 4             수민  31   생수         2
